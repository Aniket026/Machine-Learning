# %%
text = "The agents phone number is 408-555-1234. Call soon !"

# %%
'phone' in text
# Out:
# True

# %%
import re

# %%
pattern = 'phone'

# %%
re.search(pattern, text)
# Out:
# <re.Match object; span=(11, 16), match='phone'>

# %%
pattern = "NOT IN TEXT"

# %%
re.search(pattern,text)

# %%
pattern = "phone"

# %%
match = re.search (pattern, text)

# %%
match
# Out:
# <re.Match object; span=(11, 16), match='phone'>

# %%
match.span()
# Out:
# (11, 16)

# %%
match.start()
# Out:
# 11

# %%
match.end()
# Out:
# 16

# %%
text="my phone is a new phone"

# %%
match=re.search("phone",text)

# %%
match.span()
# Out:
# (3, 8)

# %%
matches = re.findall("phone" , text)

# %%
matches
# Out:
# ['phone', 'phone']

# %%
len(matches)
# Out:
# 2

# %%
for match in re.finditer("phone" , text):
    print(match.span())
# Out:
# (3, 8)
# (18, 23)

# %%
match.group()
# Out:
# 'phone'

# %%
phone=re.search(r'\d\d\d-\d\d\d-\d\d\d\d' , text)

# %%
phone.group()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 phone.group()
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
re.search(r'\d{3}-\d{3}-\d{4}',text)

# %%
phone_pattern=re.compile(r'(\d{3}) - (\d{3}) - (\d{4})')

# %%
results=re.search(phone_pattern,text)

# %%
results.group()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 results.group()
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
re.search(r"man|womne" , "This man was here. " )
# Out:
# <re.Match object; span=(5, 8), match='man'>

# %%
re.search(r"man|women" , "This women was here. " )
# Out:
# <re.Match object; span=(5, 10), match='women'>

# %%
re.findall(r".at" , "The cat in the hat sat here.")
# Out:
# ['cat', 'hat', 'sat']

# %%
re.findall(r".at" ,"The bat went splat")
# Out:
# ['bat', 'lat']

# %%
re.findall(r"...at" , "The bat went splat.")
# Out:
# ['e bat', 'splat']

# %%
re.findall(r"..at" , "The bat went splat")
# Out:
# [' bat', 'plat']

# %%
re.findall(r'\S+at',"The bat went splat")
# Out:
# ['bat', 'splat']

# %%
re.findall(r'\d$','This ends with a number 2')
# Out:
# ['2']

# %%
re.findall(r'^\d','1 is the loneliest number.')
# Out:
# ['1']

# %%
phrase = "there are 3 numbers 34 inside 5 this sentence."

# %%
text=re.findall(r'[^\d]+' ,phrase)

# %%
text
# Out:
# ['there are ', ' numbers ', ' inside ', ' this sentence.']

# %%
re.findall('[^!.?]+',phrase)
# Out:
# ['there are 3 numbers 34 inside 5 this sentence']

# %%
clane=''.join(re.findall('[^!.?]+',phrase))

# %%
clane
# Out:
# 'there are 3 numbers 34 inside 5 this sentence'

# %%
#find the word that start with cat and end with one of these options :'fish"
text='hello, would you like some catfish'
text2='hello ,would you like to take catnap ?'
text3='hello,have you seen this caterpiller'
re.search(r'cat(fish|nap|claw)',text)
# Out:
# <re.Match object; span=(27, 34), match='catfish'>

# %%
re.search(r'cat(fish|nap|claw)',text2)
# Out:
# <re.Match object; span=(30, 36), match='catnap'>

# %%
re.search(r'cat(fish|nap|claw)',text3) #none retuned
